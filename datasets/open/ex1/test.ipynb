# %%
import pickle

# %%
import os 
pwd = os.getcwd()
pwd
# Out:
# 'x:\\Datasets\\Blockchain\\xblock.pro\\eth-phishing-detection\\datasets\\open\\ex1'

# %%
# 读取shapelets.npy
import numpy as np
shapelets = np.load(pwd + '/shapelets.npy')

# %%
# 交换第一个和第二个数据
# shapelets[0], shapelets[1] = shapelets[1], shapelets[0]

# %%
len(shapelets)
# Out:
# 10

# %%
# 画出shapelets 画到一行
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 2))
# 线条粗细
plt.rcParams['lines.linewidth'] = 3
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.plot(shapelets[i])
    plt.axis('off')
plt.show()
